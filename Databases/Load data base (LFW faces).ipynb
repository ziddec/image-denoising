# %%
import sklearn
from sklearn import datasets

from matplotlib import pyplot as plt
from matplotlib.pyplot import imread
import numpy as np

# %% [markdown]
# ## Olivetti faces dataset
#
# 400 imagens de tamanho 64 x 64

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_olivetti_faces.html#sklearn.datasets.fetch_olivetti_faces

# %%
db = sklearn.datasets.fetch_olivetti_faces()
# Database com 400 rostos

# %%
db['data']
# Out:
# array([0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#        0.1570248 ], dtype=float32)

# %%
plt.imshow(db['data'])

# %%
faces = db.data
faces
# Out:
# array([[0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#         0.1570248 ],
#        [0.45454547, 0.47107437, 0.5123967 , ..., 0.15289256, 0.15289256,
#         0.15289256],
#        [0.3181818 , 0.40082645, 0.49173555, ..., 0.14049587, 0.14876033,
#         0.15289256],
#        ...,
#        [0.5       , 0.53305787, 0.607438  , ..., 0.17768595, 0.14876033,
#         0.19008264],
#        [0.21487603, 0.21900827, 0.21900827, ..., 0.57438016, 0.59090906,
#         0.60330576],
#        [0.5165289 , 0.46280992, 0.28099173, ..., 0.35950413, 0.3553719 ,
#         0.38429752]], dtype=float32)

# %%
len(faces)
# Out:
# 400

# %%
faces[0]
# Out:
# array([0.30991736, 0.3677686 , 0.41735536, ..., 0.15289256, 0.16115703,
#        0.1570248 ], dtype=float32)

# %%
len(faces[0])
# Out:
# 4096

# %%
np.sqrt(4096)
# Out:
# 64.0

# %%
face0_foto = faces[0].reshape(64, 64)

# %%
plt.imshow(face0_foto, cmap='gray')

# %% [markdown]
# ## Labeled Faces in the Wild
#
# 13233 imagens de tamanho 62 x 47

# %%
from sklearn.datasets import fetch_lfw_people

# %%
# Isso demora para rodar.
db2 = fetch_lfw_people()

# %%
db2.data
# original size 62 x 47 pixels.
# Out:
# array([[ 34.      ,  29.333334,  22.333334, ...,  14.666667,  16.      ,
#          14.      ],
#        [158.      , 160.66667 , 169.66667 , ..., 138.66667 , 135.33333 ,
#         130.33333 ],
#        [ 77.      ,  81.333336,  88.      , ..., 192.      , 145.33333 ,
#          66.333336],
#        ...,
#        [ 38.      ,  41.666668,  55.333332, ...,  66.      ,  63.666668,
#          54.333332],
#        [ 16.666666,  24.333334,  60.333332, ..., 219.      , 143.33333 ,
#          69.333336],
#        [ 58.333332,  48.      ,  20.      , ..., 116.      , 106.333336,
#         143.33333 ]], dtype=float32)

# %%
faces2 = db2['data']

# %%
plt.imshow(faces2, cmap='gray')

# %%
plt.imshow(faces2[0].reshape(62, 47), cmap='gray')

# %%
plt.imshow(faces2[1].reshape(62, 47), cmap='gray')

# %%
plt.imshow(faces2[2].reshape(62, 47), cmap='gray')

# %%
faces2.shape # são 13 mil imagens
# Out:
# (13233, 2914)

# %% [markdown]
# ## 2 Sample images
#
# será que não tem mais?

# %%
from sklearn.datasets import load_sample_images

# %%
db3 = load_sample_images()

# %%
imgs = db3['images']

# %%
plt.imshow(imgs[1], cmap='gray')
